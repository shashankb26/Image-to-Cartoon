# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in d:\anaconda\lib\site-packages (4.5.2.52)
# Requirement already satisfied: numpy>=1.14.5 in d:\anaconda\lib\site-packages (from opencv-python) (1.19.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("C:\\Users\\SHASHANK BHASKAR\\Pictures\\516438-istock-637689912.jpg")

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray,5)
edges = cv2.adaptiveThreshold(gray, 255,
                             cv2.ADAPTIVE_THRESH_MEAN_C,
                             cv2.THRESH_BINARY, 9,9)

# %%
color = cv2.bilateralFilter(img, 9, 250, 250)
cartoon = cv2.bitwise_and(color, color, mask=edges)

# %%
cv2.imshow("Image", img)
cv2.imshow("edges", edges)
cv2.imshow("Cartoon", cartoon )
cv2.waitKey(0)
cv2.destroyAllWindows()
